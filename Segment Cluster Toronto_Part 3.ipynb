# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# !conda install -c conda-forge geopy --yes

import json # library to handle JSON files
import geopy

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

##!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
# !pip install folium
import folium # map rendering library

print('Libraries imported.')
# Out:
# Solving environment: - ^C
# failed
#
# CondaError: KeyboardInterrupt
#
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/fd/a0/ccb3094026649cda4acd55bf2c3822bb8c277eb11446d13d384e5be35257/folium-0.10.1-py2.py3-none-any.whl (91kB)
#      |████████████████████████████████| 92kB 15.2MB/s eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/81/6d/31c83485189a2521a75b4130f1fee5364f772a0375f81afff619004e5237/branca-0.4.0-py3-none-any.whl
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from branca>=0.3.0->folium) (1.12.0)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.0 folium-0.10.1
# Libraries imported.

# %%
## Read data from url 
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
toronto_url = requests.get(url)
toronto_url
# Out:
# <Response [200]>

# %%
toronto_data = pd.read_html(toronto_url.text)
len(toronto_data), type(toronto_data)
# Out:
# (3, list)

# %%
## Refer to first table
toronto_data = toronto_data[0]
toronto_data.head()
# Out:
#   Postal code           Borough                Neighborhood
# 0         M1A      Not assigned                         NaN
# 1         M2A      Not assigned                         NaN
# 2         M3A        North York                   Parkwoods
# 3         M4A        North York            Victoria Village
# 4         M5A  Downtown Toronto  Regent Park / Harbourfront

# %%
## Neighborhoods separated with a comma
toronto_data = toronto_data.replace('/',', ',regex=True)

# %%
## Neighborhood will be the same as the borough if Not assigned
toronto_data.Neighborhood.replace('Not assigned',toronto_data.Borough,inplace=True)

# %%
toronto_data.tail()
# Out:
#     Postal code       Borough  \
# 175         M5Z  Not assigned
# 176         M6Z  Not assigned
# 177         M7Z  Not assigned
# 178         M8Z     Etobicoke
# 179         M9Z  Not assigned
#
#                                           Neighborhood
# 175                                                NaN
# 176                                                NaN
# 177                                                NaN
# 178  Mimico NW ,  The Queensway West ,  South of Bl...
# 179                                                NaN

# %%
toronto_data.shape
# Out:
# (180, 3)

# %%
Loc_data = pd.read_csv('http://cocl.us/Geospatial_data')

# %%
Loc_data.rename(columns={'Postal Code':'Postal code'}, inplace=True)

# %%
cols = ['Postal code']
toronto_data.join(Loc_data.set_index(cols), on=cols)
# Out:
#     Postal code           Borough  \
# 0           M1A      Not assigned
# 1           M2A      Not assigned
# 2           M3A        North York
# 3           M4A        North York
# 4           M5A  Downtown Toronto
# 5           M6A        North York
# 6           M7A  Downtown Toronto
# 7           M8A      Not assigned
# 8           M9A         Etobicoke
# 9           M1B       Scarborough
# 10          M2B      Not assigned
# 11          M3B        North York
# 12          M4B         East York
# 13          M5B  Downtown Toronto
# 14          M6B        North York
# 15          M7B      Not assigned
# 16          M8B      Not assigned
# 17          M9B         Etobicoke
# 18          M1C       Scarborough
# 19          M2C      Not assigned
# 20          M3C        North York
# 21          M4C         East York
# 22          M5C  Downtown Toronto
# 23          M6C              York
# 24          M7C      Not assigned
# 25          M8C      Not assigned
# 26          M9C         Etobicoke
# 27          M1E       Scarborough
# 28          M2E      Not assigned
# 29          M3E      Not assigned
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 32          M6E              York
# 33          M7E      Not assigned
# 34          M8E      Not assigned
# 35          M9E      Not assigned
# 36          M1G       Scarborough
# 37          M2G      Not assigned
# 38          M3G      Not assigned
# 39          M4G         East York
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 42          M7G      Not assigned
# 43          M8G      Not assigned
# 44          M9G      Not assigned
# 45          M1H       Scarborough
# 46          M2H        North York
# 47          M3H        North York
# 48          M4H         East York
# 49          M5H  Downtown Toronto
# 50          M6H      West Toronto
# 51          M7H      Not assigned
# 52          M8H      Not assigned
# 53          M9H      Not assigned
# 54          M1J       Scarborough
# 55          M2J        North York
# 56          M3J        North York
# 57          M4J         East York
# 58          M5J  Downtown Toronto
# 59          M6J      West Toronto
# 60          M7J      Not assigned
# 61          M8J      Not assigned
# 62          M9J      Not assigned
# 63          M1K       Scarborough
# 64          M2K        North York
# 65          M3K        North York
# 66          M4K      East Toronto
# 67          M5K  Downtown Toronto
# 68          M6K      West Toronto
# 69          M7K      Not assigned
# 70          M8K      Not assigned
# 71          M9K      Not assigned
# 72          M1L       Scarborough
# 73          M2L        North York
# 74          M3L        North York
# 75          M4L      East Toronto
# 76          M5L  Downtown Toronto
# 77          M6L        North York
# 78          M7L      Not assigned
# 79          M8L      Not assigned
# 80          M9L        North York
# 81          M1M       Scarborough
# 82          M2M        North York
# 83          M3M        North York
# 84          M4M      East Toronto
# 85          M5M        North York
# 86          M6M              York
# 87          M7M      Not assigned
# 88          M8M      Not assigned
# 89          M9M        North York
# 90          M1N       Scarborough
# 91          M2N        North York
# 92          M3N        North York
# 93          M4N   Central Toronto
# 94          M5N   Central Toronto
# 95          M6N              York
# 96          M7N      Not assigned
# 97          M8N      Not assigned
# 98          M9N              York
# 99          M1P       Scarborough
# 100         M2P        North York
# 101         M3P      Not assigned
# 102         M4P   Central Toronto
# 103         M5P   Central Toronto
# 104         M6P      West Toronto
# 105         M7P      Not assigned
# 106         M8P      Not assigned
# 107         M9P         Etobicoke
# 108         M1R       Scarborough
# 109         M2R        North York
# 110         M3R      Not assigned
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# 114         M7R       Mississauga
# 115         M8R      Not assigned
# 116         M9R         Etobicoke
# 117         M1S       Scarborough
# 118         M2S      Not assigned
# 119         M3S      Not assigned
# 120         M4S   Central Toronto
# 121         M5S  Downtown Toronto
# 122         M6S      West Toronto
# 123         M7S      Not assigned
# 124         M8S      Not assigned
# 125         M9S      Not assigned
# 126         M1T       Scarborough
# 127         M2T      Not assigned
# 128         M3T      Not assigned
# 129         M4T   Central Toronto
# 130         M5T  Downtown Toronto
# 131         M6T      Not assigned
# 132         M7T      Not assigned
# 133         M8T      Not assigned
# 134         M9T      Not assigned
# 135         M1V       Scarborough
# 136         M2V      Not assigned
# 137         M3V      Not assigned
# 138         M4V   Central Toronto
# 139         M5V  Downtown Toronto
# 140         M6V      Not assigned
# 141         M7V      Not assigned
# 142         M8V         Etobicoke
# 143         M9V         Etobicoke
# 144         M1W       Scarborough
# 145         M2W      Not assigned
# 146         M3W      Not assigned
# 147         M4W  Downtown Toronto
# 148         M5W  Downtown Toronto
# 149         M6W      Not assigned
# 150         M7W      Not assigned
# 151         M8W         Etobicoke
# 152         M9W         Etobicoke
# 153         M1X       Scarborough
# 154         M2X      Not assigned
# 155         M3X      Not assigned
# 156         M4X  Downtown Toronto
# 157         M5X  Downtown Toronto
# 158         M6X      Not assigned
# 159         M7X      Not assigned
# 160         M8X         Etobicoke
# 161         M9X      Not assigned
# 162         M1Y      Not assigned
# 163         M2Y      Not assigned
# 164         M3Y      Not assigned
# 165         M4Y  Downtown Toronto
# 166         M5Y      Not assigned
# 167         M6Y      Not assigned
# 168         M7Y      East Toronto
# 169         M8Y         Etobicoke
# 170         M9Y      Not assigned
# 171         M1Z      Not assigned
# 172         M2Z      Not assigned
# 173         M3Z      Not assigned
# 174         M4Z      Not assigned
# 175         M5Z      Not assigned
# 176         M6Z      Not assigned
# 177         M7Z      Not assigned
# 178         M8Z         Etobicoke
# 179         M9Z      Not assigned
#
#                                           Neighborhood   Latitude  Longitude
# 0                                                  NaN        NaN        NaN
# 1                                                  NaN        NaN        NaN
# 2                                            Parkwoods  43.753259 -79.329656
# 3                                     Victoria Village  43.725882 -79.315572
# 4                          Regent Park ,  Harbourfront  43.654260 -79.360636
# 5                   Lawrence Manor ,  Lawrence Heights  43.718518 -79.464763
# 6        Queen's Park ,  Ontario Provincial Government  43.662301 -79.389494
# 7                                                  NaN        NaN        NaN
# 8                                     Islington Avenue  43.667856 -79.532242
# 9                                     Malvern ,  Rouge  43.806686 -79.194353
# 10                                                 NaN        NaN        NaN
# 11                                           Don Mills  43.745906 -79.352188
# 12                   Parkview Hill ,  Woodbine Gardens  43.706397 -79.309937
# 13                            Garden District, Ryerson  43.657162 -79.378937
# 14                                           Glencairn  43.709577 -79.445073
# 15                                                 NaN        NaN        NaN
# 16                                                 NaN        NaN        NaN
# 17   West Deane Park ,  Princess Gardens ,  Martin ...  43.650943 -79.554724
# 18          Rouge Hill ,  Port Union ,  Highland Creek  43.784535 -79.160497
# 19                                                 NaN        NaN        NaN
# 20                                           Don Mills  43.725900 -79.340923
# 21                                    Woodbine Heights  43.695344 -79.318389
# 22                                      St. James Town  43.651494 -79.375418
# 23                                  Humewood-Cedarvale  43.693781 -79.428191
# 24                                                 NaN        NaN        NaN
# 25                                                 NaN        NaN        NaN
# 26   Eringate ,  Bloordale Gardens ,  Old Burnhamth...  43.643515 -79.577201
# 27               Guildwood ,  Morningside ,  West Hill  43.763573 -79.188711
# 28                                                 NaN        NaN        NaN
# 29                                                 NaN        NaN        NaN
# 30                                         The Beaches  43.676357 -79.293031
# 31                                         Berczy Park  43.644771 -79.373306
# 32                                 Caledonia-Fairbanks  43.689026 -79.453512
# 33                                                 NaN        NaN        NaN
# 34                                                 NaN        NaN        NaN
# 35                                                 NaN        NaN        NaN
# 36                                              Woburn  43.770992 -79.216917
# 37                                                 NaN        NaN        NaN
# 38                                                 NaN        NaN        NaN
# 39                                             Leaside  43.709060 -79.363452
# 40                                  Central Bay Street  43.657952 -79.387383
# 41                                            Christie  43.669542 -79.422564
# 42                                                 NaN        NaN        NaN
# 43                                                 NaN        NaN        NaN
# 44                                                 NaN        NaN        NaN
# 45                                           Cedarbrae  43.773136 -79.239476
# 46                                   Hillcrest Village  43.803762 -79.363452
# 47   Bathurst Manor ,  Wilson Heights ,  Downsview ...  43.754328 -79.442259
# 48                                    Thorncliffe Park  43.705369 -79.349372
# 49                        Richmond ,  Adelaide ,  King  43.650571 -79.384568
# 50                      Dufferin ,  Dovercourt Village  43.669005 -79.442259
# 51                                                 NaN        NaN        NaN
# 52                                                 NaN        NaN        NaN
# 53                                                 NaN        NaN        NaN
# 54                                 Scarborough Village  43.744734 -79.239476
# 55                    Fairview ,  Henry Farm ,  Oriole  43.778517 -79.346556
# 56                   Northwood Park ,  York University  43.767980 -79.487262
# 57                                        East Toronto  43.685347 -79.338106
# 58   Harbourfront East ,  Union Station ,  Toronto ...  43.640816 -79.381752
# 59                          Little Portugal ,  Trinity  43.647927 -79.419750
# 60                                                 NaN        NaN        NaN
# 61                                                 NaN        NaN        NaN
# 62                                                 NaN        NaN        NaN
# 63     Kennedy Park ,  Ionview ,  East Birchmount Park  43.727929 -79.262029
# 64                                     Bayview Village  43.786947 -79.385975
# 65                                           Downsview  43.737473 -79.464763
# 66                      The Danforth West ,  Riverdale  43.679557 -79.352188
# 67          Toronto Dominion Centre ,  Design Exchange  43.647177 -79.381576
# 68    Brockton ,  Parkdale Village ,  Exhibition Place  43.636847 -79.428191
# 69                                                 NaN        NaN        NaN
# 70                                                 NaN        NaN        NaN
# 71                                                 NaN        NaN        NaN
# 72                 Golden Mile ,  Clairlea ,  Oakridge  43.711112 -79.284577
# 73                          York Mills ,  Silver Hills  43.757490 -79.374714
# 74                                           Downsview  43.739015 -79.506944
# 75                    India Bazaar ,  The Beaches West  43.668999 -79.315572
# 76                    Commerce Court ,  Victoria Hotel  43.648198 -79.379817
# 77        North Park ,  Maple Leaf Park ,  Upwood Park  43.713756 -79.490074
# 78                                                 NaN        NaN        NaN
# 79                                                 NaN        NaN        NaN
# 80                                       Humber Summit  43.756303 -79.565963
# 81   Cliffside ,  Cliffcrest ,  Scarborough Village...  43.716316 -79.239476
# 82                           Willowdale ,  Newtonbrook  43.789053 -79.408493
# 83                                           Downsview  43.728496 -79.495697
# 84                                     Studio District  43.659526 -79.340923
# 85                 Bedford Park ,  Lawrence Manor East  43.733283 -79.419750
# 86   Del Ray ,  Mount Dennis ,  Keelsdale and Silve...  43.691116 -79.476013
# 87                                                 NaN        NaN        NaN
# 88                                                 NaN        NaN        NaN
# 89                                  Humberlea ,  Emery  43.724766 -79.532242
# 90                       Birch Cliff ,  Cliffside West  43.692657 -79.264848
# 91                                          Willowdale  43.770120 -79.408493
# 92                                           Downsview  43.761631 -79.520999
# 93                                       Lawrence Park  43.728020 -79.388790
# 94                                            Roselawn  43.711695 -79.416936
# 95                     Runnymede ,  The Junction North  43.673185 -79.487262
# 96                                                 NaN        NaN        NaN
# 97                                                 NaN        NaN        NaN
# 98                                              Weston  43.706876 -79.518188
# 99   Dorset Park ,  Wexford Heights ,  Scarborough ...  43.757410 -79.273304
# 100                                    York Mills West  43.752758 -79.400049
# 101                                                NaN        NaN        NaN
# 102                                   Davisville North  43.712751 -79.390197
# 103                           Forest Hill North & West  43.696948 -79.411307
# 104                    High Park ,  The Junction South  43.661608 -79.464763
# 105                                                NaN        NaN        NaN
# 106                                                NaN        NaN        NaN
# 107                                          Westmount  43.696319 -79.532242
# 108                                Wexford ,  Maryvale  43.750072 -79.295849
# 109                                         Willowdale  43.782736 -79.442259
# 110                                                NaN        NaN        NaN
# 111                                 North Toronto West  43.715383 -79.405678
# 112            The Annex ,  North Midtown ,  Yorkville  43.672710 -79.405678
# 113                           Parkdale ,  Roncesvalles  43.648960 -79.456325
# 114              Canada Post Gateway Processing Centre  43.636966 -79.615819
# 115                                                NaN        NaN        NaN
# 116  Kingsview Village ,  St. Phillips ,  Martin Gr...  43.688905 -79.554724
# 117                                          Agincourt  43.794200 -79.262029
# 118                                                NaN        NaN        NaN
# 119                                                NaN        NaN        NaN
# 120                                         Davisville  43.704324 -79.388790
# 121                   University of Toronto ,  Harbord  43.662696 -79.400049
# 122                               Runnymede ,  Swansea  43.651571 -79.484450
# 123                                                NaN        NaN        NaN
# 124                                                NaN        NaN        NaN
# 125                                                NaN        NaN        NaN
# 126        Clarks Corners ,  Tam O'Shanter ,  Sullivan  43.781638 -79.304302
# 127                                                NaN        NaN        NaN
# 128                                                NaN        NaN        NaN
# 129                      Moore Park ,  Summerhill East  43.689574 -79.383160
# 130      Kensington Market ,  Chinatown ,  Grange Park  43.653206 -79.400049
# 131                                                NaN        NaN        NaN
# 132                                                NaN        NaN        NaN
# 133                                                NaN        NaN        NaN
# 134                                                NaN        NaN        NaN
# 135  Milliken ,  Agincourt North ,  Steeles East , ...  43.815252 -79.284577
# 136                                                NaN        NaN        NaN
# 137                                                NaN        NaN        NaN
# 138  Summerhill West ,  Rathnelly ,  South Hill ,  ...  43.686412 -79.400049
# 139  CN Tower ,  King and Spadina ,  Railway Lands ...  43.628947 -79.394420
# 140                                                NaN        NaN        NaN
# 141                                                NaN        NaN        NaN
# 142   New Toronto ,  Mimico South ,  Humber Bay Shores  43.605647 -79.501321
# 143  South Steeles ,  Silverstone ,  Humbergate ,  ...  43.739416 -79.588437
# 144                    Steeles West ,  L'Amoreaux West  43.799525 -79.318389
# 145                                                NaN        NaN        NaN
# 146                                                NaN        NaN        NaN
# 147                                           Rosedale  43.679563 -79.377529
# 148                                     Stn A PO Boxes  43.646435 -79.374846
# 149                                                NaN        NaN        NaN
# 150                                                NaN        NaN        NaN
# 151                           Alderwood ,  Long Branch  43.602414 -79.543484
# 152                                          Northwest  43.706748 -79.594054
# 153                                        Upper Rouge  43.836125 -79.205636
# 154                                                NaN        NaN        NaN
# 155                                                NaN        NaN        NaN
# 156                      St. James Town ,  Cabbagetown  43.667967 -79.367675
# 157           First Canadian Place ,  Underground city  43.648429 -79.382280
# 158                                                NaN        NaN        NaN
# 159                                                NaN        NaN        NaN
# 160  The Kingsway ,  Montgomery Road ,  Old Mill North  43.653654 -79.506944
# 161                                                NaN        NaN        NaN
# 162                                                NaN        NaN        NaN
# 163                                                NaN        NaN        NaN
# 164                                                NaN        NaN        NaN
# 165                               Church and Wellesley  43.665860 -79.383160
# 166                                                NaN        NaN        NaN
# 167                                                NaN        NaN        NaN
# 168              Business reply mail Processing CentrE  43.662744 -79.321558
# 169  Old Mill South ,  King's Mill Park ,  Sunnylea...  43.636258 -79.498509
# 170                                                NaN        NaN        NaN
# 171                                                NaN        NaN        NaN
# 172                                                NaN        NaN        NaN
# 173                                                NaN        NaN        NaN
# 174                                                NaN        NaN        NaN
# 175                                                NaN        NaN        NaN
# 176                                                NaN        NaN        NaN
# 177                                                NaN        NaN        NaN
# 178  Mimico NW ,  The Queensway West ,  South of Bl...  43.628841 -79.520999
# 179                                                NaN        NaN        NaN

# %%
#Select only Toronto
only_toronto = toronto_data[toronto_data['Borough'].astype(str).str.contains("Toronto")]
only_toronto.shape
# Out:
# (39, 3)

# %%
only_toronto
# Out:
#     Postal code           Borough  \
# 4           M5A  Downtown Toronto
# 6           M7A  Downtown Toronto
# 13          M5B  Downtown Toronto
# 22          M5C  Downtown Toronto
# 30          M4E      East Toronto
# 31          M5E  Downtown Toronto
# 40          M5G  Downtown Toronto
# 41          M6G  Downtown Toronto
# 49          M5H  Downtown Toronto
# 50          M6H      West Toronto
# 58          M5J  Downtown Toronto
# 59          M6J      West Toronto
# 66          M4K      East Toronto
# 67          M5K  Downtown Toronto
# 68          M6K      West Toronto
# 75          M4L      East Toronto
# 76          M5L  Downtown Toronto
# 84          M4M      East Toronto
# 93          M4N   Central Toronto
# 94          M5N   Central Toronto
# 102         M4P   Central Toronto
# 103         M5P   Central Toronto
# 104         M6P      West Toronto
# 111         M4R   Central Toronto
# 112         M5R   Central Toronto
# 113         M6R      West Toronto
# 120         M4S   Central Toronto
# 121         M5S  Downtown Toronto
# 122         M6S      West Toronto
# 129         M4T   Central Toronto
# 130         M5T  Downtown Toronto
# 138         M4V   Central Toronto
# 139         M5V  Downtown Toronto
# 147         M4W  Downtown Toronto
# 148         M5W  Downtown Toronto
# 156         M4X  Downtown Toronto
# 157         M5X  Downtown Toronto
# 165         M4Y  Downtown Toronto
# 168         M7Y      East Toronto
#
#                                           Neighborhood
# 4                          Regent Park ,  Harbourfront
# 6        Queen's Park ,  Ontario Provincial Government
# 13                            Garden District, Ryerson
# 22                                      St. James Town
# 30                                         The Beaches
# 31                                         Berczy Park
# 40                                  Central Bay Street
# 41                                            Christie
# 49                        Richmond ,  Adelaide ,  King
# 50                      Dufferin ,  Dovercourt Village
# 58   Harbourfront East ,  Union Station ,  Toronto ...
# 59                          Little Portugal ,  Trinity
# 66                      The Danforth West ,  Riverdale
# 67          Toronto Dominion Centre ,  Design Exchange
# 68    Brockton ,  Parkdale Village ,  Exhibition Place
# 75                    India Bazaar ,  The Beaches West
# 76                    Commerce Court ,  Victoria Hotel
# 84                                     Studio District
# 93                                       Lawrence Park
# 94                                            Roselawn
# 102                                   Davisville North
# 103                           Forest Hill North & West
# 104                    High Park ,  The Junction South
# 111                                 North Toronto West
# 112            The Annex ,  North Midtown ,  Yorkville
# 113                           Parkdale ,  Roncesvalles
# 120                                         Davisville
# 121                   University of Toronto ,  Harbord
# 122                               Runnymede ,  Swansea
# 129                      Moore Park ,  Summerhill East
# 130      Kensington Market ,  Chinatown ,  Grange Park
# 138  Summerhill West ,  Rathnelly ,  South Hill ,  ...
# 139  CN Tower ,  King and Spadina ,  Railway Lands ...
# 147                                           Rosedale
# 148                                     Stn A PO Boxes
# 156                      St. James Town ,  Cabbagetown
# 157           First Canadian Place ,  Underground city
# 165                               Church and Wellesley
# 168              Business reply mail Processing CentrE

# %%
CLIENT_ID = 'TNTCFACWQML3424AQDEZSGOQE1G4MNE2DJOHRLNRNFKPEYAI' # your Foursquare ID
CLIENT_SECRET = 'UO1AR0RGUQ5K3RVLW3ZB51OG315OWBCYFJXXTC3BX5X0D1RN' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TNTCFACWQML3424AQDEZSGOQE1G4MNE2DJOHRLNRNFKPEYAI
# CLIENT_SECRET:UO1AR0RGUQ5K3RVLW3ZB51OG315OWBCYFJXXTC3BX5X0D1RN

# %%
## Setting latitude and longitude of Toronto
latitude = 43.6532
longitude = -79.3832

# %%
## Searching for Italian restaurants within 500 radius
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TNTCFACWQML3424AQDEZSGOQE1G4MNE2DJOHRLNRNFKPEYAI&client_secret=UO1AR0RGUQ5K3RVLW3ZB51OG315OWBCYFJXXTC3BX5X0D1RN&ll=43.6532,-79.3832&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e9c81e060ba08001b0c66d8'},
#  'response': {'venues': [{'id': '4c787c9181bca0936180fa14',
#     'name': 'Classic italian style pizza food truck',
#     'location': {'address': 'CNE Midway',
#      'lat': 43.652144,
#      'lng': -79.381118,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.652144,
#        'lng': -79.381118}],
#      'distance': 204,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['CNE Midway', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1cb941735',
#       'name': 'Food Truck',
#       'pluralName': 'Food Trucks',
#       'shortName': 'Food Truck',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/streetfood_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '5e594c8a3de308000870c948',
#     'name': 'Elm Street Italian Deli',
#     'location': {'address': '15 Elm Street',
#      'lat': 43.65769,
#      'lng': -79.38248,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65769,
#        'lng': -79.38248}],
#      'distance': 503,
#      'postalCode': 'M5G 1G7',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['15 Elm Street', 'Toronto ON M5G 1G7', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '573df789498e03dd8e54b166',
#     'name': 'Mustachio Italian Eatery',
#     'location': {'address': '595 Bay St',
#      'crossStreet': 'Dundas St',
#      'lat': 43.65616,
#      'lng': -79.38319,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65616,
#        'lng': -79.38319}],
#      'distance': 329,
#      'postalCode': 'M5G 2C2',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['595 Bay St (Dundas St)',
#       'Toronto ON M5G 2C2',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '4f88cf84e4b002b90ab3b9b9',
#     'name': "LA's Italian + Bar",
#     'location': {'lat': 43.65053979517576,
#      'lng': -79.38460322737672,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65053979517576,
#        'lng': -79.38460322737672}],
#      'distance': 316,
#      'cc': 'CA',
#      'country': 'Canada',
#      'formattedAddress': ['Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '51bf3866498e55ee55df8db0',
#     'name': 'The Fresh Italian',
#     'location': {'lat': 43.654991437465284,
#      'lng': -79.38789662900189,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.654991437465284,
#        'lng': -79.38789662900189}],
#      'distance': 427,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '526fe29411d2aeb3803013b0',
#     'name': 'The Fresh Italian Eatery',
#     'location': {'address': '109 McCaul Street, Unit #42',
#      'crossStreet': 'Dundas Street West',
#      'lat': 43.653889,
#      'lng': -79.390785,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.653889,
#        'lng': -79.390785}],
#      'distance': 615,
#      'postalCode': 'M5T 3K5',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['109 McCaul Street, Unit #42 (Dundas Street West)',
#       'Toronto ON M5T 3K5',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '4b4a2d09f964a520687d26e3',
#     'name': 'Sbarro',
#     'location': {'address': '220 Yonge Street',
#      'crossStreet': 'in Toronto Eaton Centre',
#      'lat': 43.655413,
#      'lng': -79.380896,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.655413,
#        'lng': -79.380896}],
#      'distance': 308,
#      'postalCode': 'M5B 2H1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['220 Yonge Street (in Toronto Eaton Centre)',
#       'Toronto ON M5B 2H1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d1ca941735',
#       'name': 'Pizza Place',
#       'pluralName': 'Pizza Places',
#       'shortName': 'Pizza',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '4b846dd4f964a520dc3431e3',
#     'name': "Little Anthony's",
#     'location': {'address': '121 Richmond St. W',
#      'crossStreet': 'at York St.',
#      'lat': 43.65029624519052,
#      'lng': -79.38451301997945,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.65029624519052,
#        'lng': -79.38451301997945}],
#      'distance': 340,
#      'postalCode': 'M5H 2K1',
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['121 Richmond St. W (at York St.)',
#       'Toronto ON M5H 2K1',
#       'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d110941735',
#       'name': 'Italian Restaurant',
#       'pluralName': 'Italian Restaurants',
#       'shortName': 'Italian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '75877692'},
#     'referralId': 'v-1587315209',
#     'hasPerk': False},
#    {'id': '516c1ef3e4b0b595c55461aa',
#     'name': 'Consolato Italiano',
#     'location': {'address': 'Beverly',
#      'crossStreet': 'Dundas',
#      'lat': 43.6540714381019,
#      'lng': -79.37584957705431,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 43.6540714381019,
#        'lng': -79.37584957705431}],
#      'distance': 599,
#      'cc': 'CA',
#      'city': 'Toronto',
#      'state': 'ON',
#      'country': 'Canada',
#      'formattedAddress': ['Beverly (Dundas)', 'Toronto ON', 'Canada']},
#     'categories': [{'id': '4bf58dd8d48988d126941735',
#       'name': 'Government Building',
#       'pluralName': 'Government Buildings',
#       'shortName': 'Government',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1587315209',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-83-550bb6f88d94> in <module>
#       1 # assign relevant part of JSON to venues
# ----> 2 venues = results['response']['name']
#       3
#       4 # tranform venues into a dataframe
#       5 dataframe = json_normalize(venues)
#
# KeyError: 'name'

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                   name      categories  \
# 0  Richtree Natural Market Restaurants      Restaurant
# 1                               Subway  Sandwich Place
#
#                               address  cc     city country  \
# 0                       14 Queen St W  CA  Toronto  Canada
# 1  123 Queen Street West, Suite # C72  CA  Toronto  Canada
#
#                              crossStreet  distance  \
# 0                                    NaN       247
# 1  At Sheraton Toronto Centre, Concourse       238
#
#                                     formattedAddress  \
# 0        [14 Queen St W, Toronto ON M5H 3X4, Canada]
# 1  [123 Queen Street West, Suite # C72 (At Sherat...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 43.65261436174172...  43.652614 -79.380231
# 1  [{'label': 'display', 'lat': 43.65119366354807...  43.651194 -79.384234
#
#   postalCode state                        id
# 0    M5H 3X4    ON  4b295e10f964a520ba9d24e3
# 1    M5H 3M9    ON  50aff967e4b07ba2ce4a1c3c

# %%
dataframe.name
# Out:
# 0    Richtree Natural Market Restaurants
# 1                                 Subway
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around Toronto

# add a red circle marker to represent Toronto
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Toronto',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.name):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
