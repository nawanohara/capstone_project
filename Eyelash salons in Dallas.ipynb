# %% [markdown]
# # Week 1

# %% [markdown]
# ## Problem and Background

# %% [markdown]
# Dallas metroplex in Texas is growing in population.  Due to favorable tax conditions, many companies are moving their headquarters to Dallas.  Families and individuals are also enjoying relocations to the Dallas area where they can enjoy a no-state tax environment and property is still abundant and affordable.  It has consistently been ranked as a great city for business and entrepreneurship.
#
# Against this backdrop, the eyelash extension industry is booming and growing.  Between 2019-2024, the industry is expected to reach $1.5 billion in annual product sales.  Consumers are turning to eyelash extension salons to get their customized lash looks, similar to going to their favorite hair salons.
#
# In order to capitalize in this growth market within the Dallas metroplex, this study explores locations suited for opening a franchise store which provides lash services.

# %% [markdown]
# ## Data

# %% [markdown]
# By accessing Foursquare data, the study explores current locations of lash studios in the Dallas metroplex.  This data will be used to identify which areas are underserved and therefore good locations to open new stores.

# %% [markdown]
# # Week 2 - Final Report

# %% [markdown]
# Contents
# 1. Introduction Section :
#
# 1.1 Discussion of the "background situation" leading to the problem at hand:
#
# 1.2 Problem to be resolved
#
# 1.3 Audience for this project.
#
# 2. Data Section:
#
# 2.1 Data of Current Situation (current residence place)
#
# 2.2 Data required to resolve the problem
#
# 2.3 Data sources and data manipulation
#
# 3. Methodology section :
#
# 3.1 Process steps and strategy to resolve the problem
#
# 3.2 Data Science Methods, machine learing, mapping tools and exploratory data analysis.
#
# 4. Results Section
#
# Discussion of the results and how they help to take a decision.
#
# 5. Discussion Section
#
# Elaboration and discussion on any observations and/or recommendations for improvement.
#
# 6. Conclusion Section
#
# Decision taken and Report Conclusion.

# %% [markdown]
# ## 1. Introduction Section:

# %% [markdown]
# ### 1.1 Scenario and Background

# %% [markdown]
# Dallas metroplex in Texas is growing in population.  Due to favorable tax conditions, many companies are moving their headquarters to Dallas.  Families and individuals are also enjoying relocations to Dallas where they can enjoy a no-state tax environment and property is still abundant and affordable.  It has consistently been ranked as a great city for business and entrepreneurship.

# %% [markdown]
# ### 1.2 Problem to be Resolved:

# %% [markdown]
# Against this backdrop, the eyelash extension industry is booming and growing. Between 2019-2024, the industry is expected to reach $1.5 billion in annual product sales. Consumers are turning to eyelash extension salons to get their customized lash looks, similar to going to their favorite hair salons.
#
# In order to capitalize on this explosive industry within a growing city, the study aims to identify locations that are suitable to opening new stores.

# %% [markdown]
# ### 1.3 Interested Audience:

# %% [markdown]
# This study would be interesting to anyone currently in the beauty industry or anyone trying to get into the eyelash extension market in the Dallas metroplex.

# %% [markdown]
# ## 2. Data Section:

# %% [markdown]
# ### 2.1 Data of Current Situation

# %% [markdown]
# The study will look at the Dallas metroplex and see where population is growing.  This will be the basis of current market situation.

# %% [markdown]
# ### 2.2 Data Required to Resolve the Problem

# %% [markdown]
# Then, study will locate current eyelash extension stores in the metroplex and try to identify pockets of neighrhoods that are underserved.

# %% [markdown]
# ### 2.3 Sources and Manipulation

# %% [markdown]
# Various websites regarding the growth of the eyelash extension industry was used to come up with the thesis.  Wikipedia website was used to come up with approximate population growth.  Although the data found is from 2017, this is closest to current year.  Finally Foursquare was used to come up with the eyelash extension studio locations.

# %% [markdown]
# ## 3. Methodology Section:

# %% [markdown]
# ### 3.1 Process steps and Strategy to Resolve Problem

# %% [markdown]
# First, we looked into the data by wikipedia.  The overall population has grown from 6.4 million to 7.4 million people between 2010 and 2017.  There is a county-by-county level data that we will be extracting which shows the explosive growth that is happening Dallas-wide.  Second, we will be connecting to Foursquare to look up the locations of existing eyelash etension stores.  Based on these datapoints, we should be able to tell which markets are underserved.

# %% [markdown]
# ### 3.2 Data Science Methods

# %% [markdown]
# *Population Growth in Dallas*

# %%
import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis
import requests # library to handle requests
from pandas.io.json import json_normalize

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# !pip install folium
import folium # map rendering library
##import lxml.html as lh

# !pipa install geopy 
from geopy.geocoders import Nominatim

# !pip install Beautifulsoup4

print('Libraries imported.')
# Out:
# ...
# /usr/bin/sh: pipa: command not found
# ...
# Libraries imported.

# %%
## Read table from url 
from bs4 import BeautifulSoup as bs

url = 'https://en.wikipedia.org/wiki/Dallas%E2%80%93Fort_Worth_metroplex'
r = requests.get(url)
soup = bs(r.content,'lxml')

# %%
## Get the table and convert to df
table = soup.find_all('table',class_='wikitable')
df = pd.read_html(str(table))[0]
df.iloc[:, : 4]
# Out:
#               County  2017 Estimate  2010 Census   Change
# 0      Collin County         969603       782341  +23.94%
# 1      Dallas County        2618148      2368139  +10.56%
# 2      Denton County         836210       662614  +26.20%
# 3       Ellis County         173620       149610  +16.05%
# 4        Hood County          58273        51182  +13.85%
# 5        Hunt County          93872        86129   +8.99%
# 6     Johnson County         167301       150934  +10.84%
# 7     Kaufman County         122883       103350  +18.90%
# 8      Parker County         133463       116927  +14.14%
# 9    Rockwall County          96788        78337  +23.55%
# 10  Somervell County           8845         8490   +4.18%
# 11    Tarrant County        2054475      1809034  +13.57%
# 12       Wise County          66181        59127  +11.93%
# 13             Total        7399662      6426214  +15.15%

# %% [markdown]
# *Existing Eyelash Extension Studios*

# %%
CLIENT_ID = 'TNTCFACWQML3424AQDEZSGOQE1G4MNE2DJOHRLNRNFKPEYAI' # your Foursquare ID
CLIENT_SECRET = 'UO1AR0RGUQ5K3RVLW3ZB51OG315OWBCYFJXXTC3BX5X0D1RN' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: TNTCFACWQML3424AQDEZSGOQE1G4MNE2DJOHRLNRNFKPEYAI
# CLIENT_SECRET:UO1AR0RGUQ5K3RVLW3ZB51OG315OWBCYFJXXTC3BX5X0D1RN

# %%
address = 'Dallas, Texas'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 32.7762719 -96.7968559

# %%
search_query = 'Eyelash extensions'
radius = 50000
print(search_query + ' .... OK!')
# Out:
# Eyelash extensions .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=TNTCFACWQML3424AQDEZSGOQE1G4MNE2DJOHRLNRNFKPEYAI&client_secret=UO1AR0RGUQ5K3RVLW3ZB51OG315OWBCYFJXXTC3BX5X0D1RN&ll=32.7762719,-96.7968559&v=20180604&query=Eyelash extensions&radius=50000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5eaf24c0e826ac001b3e6c35'},
#  'response': {'venues': [{'id': '582210b58edd3a06f37f596e',
#     'name': 'Face Studio Garland Permanent Cosmetics, Eyelash Extensions & Eyelash Extensions Training',
#     'location': {'address': '4280 Lavon Drive #280, Inside Firewheel Salons Suite 60',
#      'lat': 32.956452,
#      'lng': -96.616293,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 32.956452,
#        'lng': -96.616293}],
#      'distance': 26216,
#      'postalCode': '75040',
#      'cc': 'US',
#      'city': 'Garland',
#      'state': 'TX',
#      'country': 'United States',
#      'formattedAddress': ['4280 Lavon Drive #280, Inside Firewheel Salons Suite 60',
#       'Garland, TX 75040',
#       'United States']},
#     'categories': [{'id': '54541900498ea6ccd0202697',
#       'name': 'Health & Beauty Service',
#       'pluralName': 'Health & Beauty Services',
#       'shortName': 'Health & Beauty',
# ...

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                                           categories  hasPerk  \
# 0  [{'id': '54541900498ea6ccd0202697', 'name': 'H...    False
# 1  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...    False
# 2  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...    False
# 3  [{'id': '4bf58dd8d48988d110951735', 'name': 'S...    False
# 4  [{'id': '4bf58dd8d48988d10c951735', 'name': 'C...    False
#
#                          id  \
# 0  582210b58edd3a06f37f596e
# 1  50d38b18e4b0e55860d64235
# 2  523fcef92fc695a8f5333541
# 3  524d971611d26e06a4f00417
# 4  5265771411d282e5e64afeac
#
#                                     location.address location.cc  \
# 0  4280 Lavon Drive #280, Inside Firewheel Salons...          US
# 1                                                NaN          US
# 2                     2693 Preston Rd Ste 1080 Rm 17          US
# 3                                    1116 S Akard St          US
# 4                                     2700 Canton St          US
#
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name  \
# 0   Face Studio Garland Permanent Cosmetics, Eyela...
# 1                       Fab-U-Lash Eyelash Extensions
# 2                Swanky - Hair and Eyelash Extensions
# 3                      Good Hair & Co. Extensions Bar
# 4                                      Angelic Lashes
# 5                    Lashittude Extensions and Boutik
# 6   The Beauty Box Salon - Dallas Extensions, Wigs...
# 7                               Haute Pink Extensions
# 8                        Bravadas Wigs Store - Dallas
# 9                              Eyelashes by Stephanie
# 10                       Millie Pearl Hair Extensions
# 11                                   The Eyelash Diva
# 12                                   My Amazing Looks
# 13                           Hair Extensions for Sale
# 14                     Indique Virgin Hair Extensions
# 15                               Extensions by design
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=10) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Dallas',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## 4. Results Section:

# %% [markdown]
# Based on the above study, both Tarrant County and Kaufman County seem like great candidates to open a new eyelash extension store.  Both counties have recently experienced double digit growth in population and currently there are no nearby stores providing this service.  People residing in these counties would have to travel to Dallas or northward to access these stores.
#
# Fort Worth and Arlington are cities within Tarrant County and both cities have many companies and jobs.  That entails people residing in even outer residential areas would travel to these cities for work which creates even more foot traffic to this area.
#
# Both Tarrant and Kaufman counties are great locations to start investigating further on opening stores.

# %% [markdown]
# ## 5. Discussion Section:

# %% [markdown]
# Next steps would be to gather even more data around these counties.  For example, it would be useful to understand commercial activity in these areas.  Is there a main road with heavy traffic?  Where are offices located because many people prefer convenience and getting their lashes done during their lunch breaks or on their commute to/from their work.

# %% [markdown]
# ## 6. Conclusion Section:

# %% [markdown]
# Tarrant County and Kaufman County - are both great candidates to open a new eyelash extension store.  Further fact finding is necessary but this data science study immediately got me started in the right direction.
